# %%
from pylab import *
import numpy as np
x=np.linspace(-pi/2,pi/2,100)
f=np.sin(x)
plot(x,f)
show()

# %%
x=np.linspace(1,10,100)
f=np.cos(x)
plot(x,f)
show()

# %%
x=np.linspace(0,20,100)
f=np.log(x)
plot(x,f)
show()
# Out:
# <ipython-input-5-db42dcaf70b0>:2: RuntimeWarning: divide by zero encountered in log
#   f=np.log(x)

# %%
x=np.linspace(1,10,100)
f=np.exp(1/x**2)
plot(x,f)
show()

# %%
x=np.linspace(1,10,100)
f=2**x
plot(x,f)
show()

# %%
x=np.linspace(0,2*pi,100)
f=np.exp(2*x)+np.sin(x)**2+3*x**2
plot(x,f)
show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.arange(0,5)
y=x**2+2
plt.plot(x,y)
plt.show()
x=np.arange(5,10)
y=np.exp(x)
plt.plot(x,y)
plt.show()
x=np.arange(10,15)
y=np.sin(x)
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x1=['mon','tue','wed','Thu','Fri','sat']
y1=[62,78,34,58,45,67]
plt.plot(x1,y1,label="maths")
x2=['mon','tue','wed','Thu','Fri','sat']
y2=[48,55,76,68,49,53]
plt.plot(x2,y2,label="computer")
x3=['mon','tue','wed','Thu','Fri','sat']
y3=[55,64,57,79,63,42]
plt.plot(x3,y3,label="electronics")
plt.xlabel("days")
Text(0.5,0,'days')
plt.ylabel("no of students")
Text(0.0,5,'No of students')
plt.title("line graph of attendance")
Text(0.5,1,"line graph of attendance")
plt.legend()
plt.show()

# %%
mathematics=[65,78,34,58,45,67]
computer=[48,55,76,68,49,53]
electronics=[55,64,57,79,63,42]
Days=['mon','tue','wed','thu','fri','sat']
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.scatter(Days,mathematics,color='r')
ax.scatter(Days,computer,color='b')
ax.scatter(Days,electronics,color='g')
ax.set_xlabel('Days')
Text('Days')
ax.set_ylabel('No of students')
Text('No of students')
plt.title("scatter graph of attendance")
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
left=[1,2,3,4,5,6]
height=[64,78,43,61,24,87]
tick_label=['mon','tue','wed','thu','fri','sat']
plt.bar(left,height,tick_label=tick_label,width=0.8,color=['blue','green'])
plt.xlabel("days")
Text(0.5,0,'Days')
plt.ylabel('No of students')
Text(0.5,0,"no of students")
plt.title("Students attendance record")
Text(0.5,1.0,"student attendance record")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array(['action','romance','Drama','scifi','Horror'])
y=np.array([23,13,9,29,26])
plt.bar(x,y,1)
plt.xlabel('type of movie')
plt.Text("type of movie")
plt.ylabel('no of friends')
plt.Text('no of friends')
plt.title('kind of movie liked by friends')
plt.Text('kind of movie liked by friends')
plt.show()
# Out:
# <BarContainer object of 5 artists>

# %%
import numpy as np
import matplotlib.pyplot as plt
y=np.array([23,13,9,29,26])
mylabels=(['action','romance','Drama','scifi','Horror'])
plt.title('kind of movie liked by friends')
plt.Text('kind of movie liked by friends')
plt.pie(y,labels=mylabels)
plt.show()

# %% [markdown]
# ## Practical 2

# %%
from mpl_toolkits import mplot3d
import numpy as np
from pylab import *
def f(x,y):
  return np.sin(x**2+y**2)
x=np.linspace(-6,6,30)
y=np.linspace(-6,6,30)
X,Y=np.meshgrid(x,y)
Z=f(X,Y)
ax=axes(projection='3d')
ax.contour3D(X,Y,Z,50)
xlabel('x')
ylabel('y')
title('sin(x^2+y^2)')
legend()
show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
from mpl_toolkits import mplot3d
import numpy as np
from pylab import *
def f(x,y):
  return np.sin(x)+np.cos(y)
x=np.linspace(-10,10,10)
y=np.linspace(-10,10,10)
X,Y=np.meshgrid(x,y)
Z=f(X,Y)
ax=axes(projection='3d')
ax.contour3D(X,Y,Z,50)
xlable='x'
ylable='y'
title('sin(x)+cos(y)')
show()

# %%
from mpl_toolkits import mplot3d
from pylab import *
import numpy as np
def f(x,y):
  return np.sin(x)-np.exp(x)+3*x**2-np.log(x)
x=np.linspace(0,pi/2,10)
y=np.linspace(0,pi/2,10)
X,Y=np.meshgrid(x,y)
Z=f(X,Y)
ax=axes(projection='3d')
ax.contour3D(X,Y,Z,50)
xlable='x'
ylable='y'
show()
# Out:
# <ipython-input-5-d98c328192e6>:5: RuntimeWarning: divide by zero encountered in log
#   return np.sin(x)-np.exp(x)+3*x**2-np.log(x)

# %%
import numpy as np
from pylab import *
x=np.linspace(-5,5,100)
y=np.exp(-x**2)
plot(x,y,"-.^g",label="$y=e^{-x^2}$")
xlabel('x')
ylabel('y')
title("exp(-x^2)")
legend()
show()

# %%
from mpl_toolkits import mplot3d
import matplotlib.pyplot as plt
import numpy as np
fig=plt.figure(figsize=(4,4))
ax=fig.add_subplot(111,projection='3d')
ax.scatter(70,-25,15,c='k',marker='d')
plt.show()

# %%
from mpl_toolkits import mplot3d
import matplotlib.pyplot as plt
import numpy as np
fig=plt.figure()
ax=plt.axes(projection='3d')
z=np.linspace(0,10,30)
x=z*np.cos(2*z)
y=z*np.sin(2*z)
ax.plot3D(x,y,z,'red')
ax.set_title('3d line plot')
plt.show()

# %%
from mpl_toolkits import mplot3d
import numpy as np
from pylab import *
def f(x,y):
  return x**2+y**2
x=np.linspace(0.2*pi,30)
y=np.linspace(0,2*pi,30)
X,Y=np.meshgrid(x,y)
Z=f(X,Y)
ax=axes(projection='3d')
ax.plot_wireframe(X,Y,Z,rstride=2,cstride=2)
xlabel('x')
ylabel('y')
legend()
show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
from mpl_toolkits import mplot3d
import numpy as np
from pylab import *
def f(x,y):
  return x*np.exp(-x**2-y**2)
x=np.linspace(-pi,pi,30)
y=np.linspace(-pi,pi,30)
X,Y=np.meshgrid(x,y)
Z=f(X,Y)
ax=axes(projection='3d')
ax.plot_wireframe(X,Y,Z,rstride=2,cstride=2)
xlabel('x')
ylabel('y')
legend()
show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## Practical 3 and 4

# %%
from sympy import *

# %%
p=Point(3,-1)

# %%
#reflection through x axis
p.transform(Matrix([[1,0,0],[0,-1,0],[0,0,1]]))
# Out:
# Point2D(3, 1)

# %%
#scaling in x co-ordinates by factor 2
p.scale(2,0)
# Out:
# Point2D(6, 0)

# %%
#scaling in y co-ordinates by factor 1.5
p.scale(0,1.5)
# Out:
# Point2D(0, -3/2)

# %%
#reflection through line y=x
x,y=symbols('x y')
p.reflect(Line(x-y+0))
# Out:
# Point2D(-1, 3)

# %%
p=Point(3,8)

# %%
p.transform(Matrix([[1,0,0],[0,-1,0],[0,0,1]]))
#reflection through the x axis
# Out:
# Point2D(3, -8)

# %%
#scaling in x axis by 6
p.scale(6,0)
# Out:
# Point2D(18, 0)

# %%
#rotation about origin through an angle 30
p.rotate(pi/6)
# Out:
# Point2D(-4 + 3*sqrt(3)/2, 3/2 + 4*sqrt(3))

# %%
#reflection through the line y=-x
x,y=symbols('x y')
p.reflect(Line(x+y+0))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-75-49cfc84da421> in <cell line: 3>()
#       1 #reflection through the line y=-x
#       2 x,y=symbols('x y')
# ----> 3 p.reflect(Line(x+y+0))
#
# NameError: name 'p' is not defined

# %% [markdown]
# Q2

# %%
p=Point(-2,4)
#shearing in y direction by 7
p.transform(Matrix([[1,7,0],[0,1,0],[0,0,1]]))
# Out:
# Point2D(-2, -10)

# %%
#scaling in x and y direction by 7/2 and 7
p.scale(7/2,7)
# Out:
# Point2D(-7, 28)

# %%
#shearing in x and y by 4 and 7 units
p.transform(Matrix([[1,7,0],[4,1,0],[0,0,1]]))
# Out:
# Point2D(14, -10)

# %%
#rotation about origin by an angle 60
p.rotate(pi/3)
# Out:
# Point2D(-2*sqrt(3) - 1, 2 - sqrt(3))

# %% [markdown]
# Q3

# %%
from sympy import *

# %%
A=Point(3,3)
B=Point(4,6)
C=Point(5,4)
D=Point(4,2)
E=Point(2,2)
P=Polygon(A,B,C,D,E)

# %%
P.translate(-2,1)
# Out:
# Polygon(Point2D(1, 4), Point2D(2, 7), Point2D(3, 5), Point2D(2, 3), Point2D(0, 3))

# %% [markdown]
# Q5

# %%
A=Point(5,-2)
B=Point(4,3)
S=Segment(A,B)

# %%
#rotate through angle pi
s1=S.rotate(pi)
s1
# Out:
# Segment2D(Point2D(-5, 2), Point2D(-4, -3))

# %%
#scaling in x co-ordinate by 2 unit
s2=s1.scale(2,0)
s2
# Out:
# Segment2D(Point2D(-10, 0), Point2D(-8, 0))

# %%
#reflection through the line y=x
x,y=symbols('x y')
s3=s2.reflect(Line(x+y+0))
s3
# Out:
# Segment2D(Point2D(0, 10), Point2D(0, 8))

# %%
#shearing in x by 4 units
Points=s3.points
p=Points[0]
q=Points[1]

# %%
p1=p.transform(Matrix([[1,0,0],[4,1,0],[0,0,1]]))
p1
# Out:
# Point2D(40, 10)

# %%
q1=p.transform(Matrix([[1,0,0],[4,1,0],[0,0,1]]))
q1
# Out:
# Point2D(40, 10)

# %%
S=Segment(p1,q1)
S
# Out:
# Point2D(40, 10)

# %% [markdown]
# Q7

# %%
A=Point(4,-1)
B=Point(3,0)
p1=A.transform(Matrix([[1,0,0],[9,1,0],[0,0,1]]))
q1=B.transform(Matrix([[1,0,0],[9,1,0],[0,0,1]]))
s=Segment(p1,q1)
s
# Out:
# Segment2D(Point2D(-5, -1), Point2D(3, 0))

# %%
#rotate through the origin by angle pi
s1=s.rotate(pi)
s1
# Out:
# Segment2D(Point2D(5, 1), Point2D(-3, 0))

# %%
#scale through x by factor 2
s2=s1.scale(2,0)
s2
# Out:
# Segment2D(Point2D(10, 0), Point2D(-6, 0))

# %%
#reflect through the line y=x
x,y=symbols('x y')
s3=s2.reflect(Line(y-x+0))
s3
# Out:
# Segment2D(Point2D(0, 10), Point2D(0, -6))

# %% [markdown]
# Q8

# %%
from mpl_toolkits import mplot3d
import matplotlib.pyplot as plt
import numpy as np
fig=plt.figure(figsize=(4,4))
ax=fig.add_subplot(111,projection='3d')
ax.scatter(70,-25,15,c='k',marker='d')
ax.scatter(50,72,-45,c='g',marker='*')
ax.scatter(58,-82,65,c='g',marker='d')
ax.scatter(20,72,-45,c='r',marker='*')
plt.show()

# %% [markdown]
# ## Practical 5 And 6

# %% [markdown]
# Q1

# %%
from sympy import *

# %%
p=Point(2,2)

# %%
#rotate through the angle pi/4
p.rotate(pi/4)
# Out:
# Point2D(0, 2*sqrt(2))

# %% [markdown]
# Q2

# %%
#translate the point in x and y axis
p=Point(3,3)
p.transform(Matrix([[-1,0,0],[0,-1,0],[0,0,1]]))
# Out:
# Point2D(-3, -3)

# %% [markdown]
# Q3

# %%
p=Point(1,0)
#rotation about 90deg
p.rotate(pi/2)
# Out:
# Point2D(0, 1)

# %% [markdown]
# Q4

# %%
p=Point(1,1)
#reflection through origin
p.transform(Matrix([[-1,0,0],[0,-1,0],[0,0,1]]))
# Out:
# Point2D(-1, -1)

# %% [markdown]
# ### Practical 7 & 8

# %%
from sympy import *

# %%
A=Point(0,0)
B=Point(2,0)
C=Point(2,3)
D=Point(1,6)
p=Polygon(A,B,C,D)
p.rotate(pi)
# Out:
# Polygon(Point2D(0, 0), Point2D(-2, 0), Point2D(-2, -3), Point2D(-1, -6))

# %%
A=Point(0,2)
B=Point(5,2)
C=Point(3,0)
Point.is_collinear(A,B,C)
# Out:
# False

# %%
l=Line(Point(0,2),Point(5,2))
l.equation()
C=Point(3,0)
l.distance(C)
# Out:
# 2

# %%
A=Point(2,1)
B=Point(4,-1)
A1=A.transform(Matrix([[1,2,0],[2,1,0],[0,0,1]]))
B1=B.transform(Matrix([[1,2,0],[2,1,0],[0,0,1]]))
L=Line(A1,B1)
L.equation()
# Out:
# -2*x - 2*y + 18

# %%
A,B,C,D=[(0,0),(1,0),(2,2),(1,4)]
P=Polygon(A,B,C,D)
x=P.area
y=P.perimeter
print(x,',',y)
# Out:
# 4 , 1 + sqrt(17) + 2*sqrt(5)

# %% [markdown]
# ### Pracical 9 and 10

# %%
from pulp import *

# %%
lpp=LpProblem(name="LPP",sense=LpMaximize)
x=LpVariable("x",lowBound=0)
y=LpVariable("y",lowBound=0)
lpp+=(4*x+6*y<=24)
lpp+=(5*x+3*y<=15)
lpp+=(150*x+7*y)
lpp
# Out:
# LPP:
# MAXIMIZE
# 150*x + 7*y + 0
# SUBJECT TO
# _C1: 4 x + 6 y <= 24
#
# _C2: 5 x + 3 y <= 15
#
# VARIABLES
# x Continuous
# y Continuous

# %%
lpp.solve()
# Out:
# 1

# %%
lpp.objective.value()
# Out:
# 450.0

# %%
x.value()
# Out:
# 3.0

# %%
y.value()
# Out:
# 0.0

# %%
from mpl_toolkits import mplot3d
import numpy as np
from pylab import *
def f(x,y):
  return np.sin((x**2)+(y**2))
X,Y=np.meshgrid(x,y)
Z=f(X,Y)
ax=axes(projection='3d')
ax.contour3D(X,Y,Z,50)
title('sin(x**2+y**2)')
xlabel='x'
ylabel='y'

# %%
from sympy import *
A=Point(1,0)
B=Point(2,-1)

# %%
s=Segment(A,B)
s.rotate(pi/2)
# Out:
# Segment2D(Point2D(0, 1), Point2D(1, 2))

# %%
A=Point(0,0)
B=Point(2,0)
C=Point(2,3)
D=Point(1,6)
P=Polygon(A,B,C,D)

# %%
P.rotate(pi/2)
# Out:
# Polygon(Point2D(0, 0), Point2D(0, 2), Point2D(-3, 2), Point2D(-6, 1))

# %%
A,B,C=[(0,0),(4,0),(2,4)]
T=Triangle(A,B,C)

# %%
T.is_isosceles()
# Out:
# True

# %%
from pulp import *

# %%
lpp=LpProblem(name="LPP",sense=LpMaximize)
x=LpVariable("x",lowBound=0)
y=LpVariable("y",lowBound=0)
lpp+=(2*x-2*y>=1)
lpp+=(x+y>=2)
lpp+=(x+y)
lpp
# Out:
# LPP:
# MAXIMIZE
# 1*x + 1*y + 0
# SUBJECT TO
# _C1: 2 x - 2 y >= 1
#
# _C2: x + y >= 2
#
# VARIABLES
# x Continuous
# y Continuous

# %%
lpp.solve()
# Out:
# -2

# %%
lpp.objective.value()
# Out:
# 0.0

# %%
x.value()
# Out:
# 0.0

# %%
y.value()
# Out:
# 0.0

# %%
lpp=LpProblem(name='lpp',sense=LpMinimize)
x=LpVariable('x',lowBound=0)
y=LpVariable('y',lowBound=0)
lpp+=(x>=6)
lpp+=(y>=6)
lpp+=(x+y<=11)
lpp+=(x+y)
lpp
# Out:
# lpp:
# MINIMIZE
# 1*x + 1*y + 0
# SUBJECT TO
# _C1: x >= 6
#
# _C2: y >= 6
#
# _C3: x + y <= 11
#
# VARIABLES
# x Continuous
# y Continuous

# %%
lpp.solve()
# Out:
# -1

# %%
lpp.objective.value()
# Out:
# 12.0

# %%
x.value()
# Out:
# 6.0

# %%
y.value()
# Out:
# 6.0

# %%
P=Point(4,-2)

# %%
P.transform(Matrix([[-1,0,0],[0,1,0],[0,0,1]]))
# Out:
# Point2D(-4, -2)

# %%
P.scale(7,0)
# Out:
# Point2D(28, 0)

# %%
P.transform(Matrix([[1,3,0],[0,1,0],[0,0,1]]))
# Out:
# Point2D(4, 10)

# %%
#reflection through the line y=-x
x,y=symbols('x y')
P.reflect(Line(-x+y+0))
# Out:
# Point2D(-2, 4)

# %%
from pylab import *
import numpy as np
x=np.linspace(-1,1,100)
f=x**2
g=x**3
plot(x,f)
plot(g,f)

# %%
from pylab import *
import numpy as np
x=np.linspace(-5,5,100)
f=np.exp(-x**2)
plot(x,f,"-.^g",label='$(-x**2)$')

# %%
import matplotlib.pyplot as plt
from pylab import *
x=np.array(['clothing','food','rent','petrol','misc'])
y=np.array([600,4000,2000,1500,700])
plt.bar(x,y,color='green')
plt.title('expenditure')
text='expenditure'
plt.xlabel('items')
text='items'
plt.ylabel('amount')
text='amount'

# %%
# !pip install pulp
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.7/17.7 MB 42.3 MB/s eta 0:00:00
# ...

# %%
from pulp import *

# %%
lpp=LpProblem(name='lpp',sense=LpMaximize)
x=LpVariable('x',lowBound=0)
y=LpVariable('y',lowBound=0)
lpp+=(4*x+6*y<=24)
lpp+=(5*x+3*y<=15)
lpp+=(150*x+75*y)
lpp
# Out:
# lpp:
# MAXIMIZE
# 150*x + 75*y + 0
# SUBJECT TO
# _C1: 4 x + 6 y <= 24
#
# _C2: 5 x + 3 y <= 15
#
# VARIABLES
# x Continuous
# y Continuous

# %%
lpp.solve()
# Out:
# 1

# %%
lpp.objective.value()
# Out:
# 450.0

# %%
x.value()
# Out:
# 3.0

# %%
y.value()
# Out:
# 0.0

# %%
from mpl_toolkits import mplot3d
from pylab import *
import numpy as np
def f(x,y):
  return np.sin((x**2)+(y**2))
x=np.linspace(0,10,50)
y=np.linspace(0,10,50)
X,Y=np.meshgrid(x,y)
Z=f(X,Y)
ax=axes(projection='3d')
ax.contour3D(X,Y,Z,50)
title('X**2+y**2')
xlabel='x'
ylabel='y'
show()

# %%
import matplotlib.pyplot as plt
x=np.array(['maths','Science','English','Marathi','Hindi'])
y=np.array([68,90,70,85,91])
plt.bar(x,y,)
plt.title('result')
plt.xlabel('subjects')
plt.ylabel('marks')
# Out:
# Text(0, 0.5, 'marks')

# %%
A=Point(0,2)
B=Point(5,2)
C=Point(3,0)
Point.is_collinear(A,B,C)
# Out:
# False

# %%
L=Line(A,B)

# %%
L.distance(C)
# Out:
# 2

# %%
A=Point(0,0)
B=Point(6,0)
C=Point(4,4)
T=Triangle(A,B,C)

# %%
T.area
# Out:
# 12

# %%
T.perimeter
# Out:
# 2*sqrt(5) + 4*sqrt(2) + 6
